# %%
#General imports
import Degeneration as DegGen
import matplotlib.pyplot as plt
import ImageHelper as ImgHelper
from scipy import misc as scipyMisc

# %%
#Load resource - resource folder with ppm images is needed in Medusa folder
img = ImgHelper.load_ppm_image("images/70.ppm")
plt.imshow(img)
plt.show()

# %%
#Local Degeneration 
import AphroditeTraining as ApTrain
import numpy as np

# Load model - Trained model is needed in Medusa folder
aphrodite = ApTrain.load_model('Aphrodite.h5')
#Load resource - resource folder with ppm images is needed in Medusa folder
img = ImgHelper.load_ppm_image("resources/00001_00027.ppm")

#In case of unexpected behavior check, if class of aphrodite.predict(img) matches the class of your image with LabelDictionary
imgClass = np.where(aphrodite.predict(np.expand_dims(img,0))[0] == 1)[0][0]
print("Aphrodite predicts the image belongs to class: ", imgClass)

ans = DegGen.degenerate(aphrodite, img, imgClass, DegGen._noise, iterations=1000, maxloops=5000)
scipyMisc.imsave("resources/localDegenerated.png",ans[1])
plt.imshow(ans[1])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-2c99c74042af> in <module>
#       4
#       5 # Load model - Trained model is needed in Medusa folder
# ----> 6 aphrodite = ApTrain.load_model('Aphrodite.h5')
#       7 #Load resource - resource folder with ppm images is needed in Medusa folder
#       8 img = ImgHelper.load_ppm_image("resources/00001_00027.ppm")
#
# ~\PythonWorkplace\Medusa\Medusa\AphroditeTraining.py in load_model(path)
#     104         path,
#     105         custom_objects=None,
# --> 106         compile=False
#     107     )
#     108     loaded.compile(optimizer=tf.train.AdamOptimizer(),
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     217   opened_new_file = not isinstance(filepath, h5py.File)
#     218   if opened_new_file:
# --> 219     f = h5py.File(filepath, mode='r')
#     220   else:
#     221     f = filepath
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# --> 142         fid = h5f.open(name, flags, fapl=fapl)
#     143     elif mode == 'r+':
#     144         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'Aphrodite.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
#Remote Degeneration

#Load resource - resource folder with ppm images is needed in Medusa folder
img = ImgHelper.load_ppm_image("resources/00001_00027.ppm")

ans = DegGen.remoteDegenerate(img, DegGen._smooth)
scipyMisc.imsave("resources/remoteDegenerated.png",ans[1])
plt.imshow(ans[1])
# Out:
# StartConfidence: 0.98910248
# Score: 0.94459051 Depth: 0 Loop: 1
# Score: 0.94459051 Depth: 0 Loop: 2
# Score: 0.94459051 Depth: 0 Loop: 3
# Score: 0.94459051 Depth: 0 Loop: 4
# Score: 0.94459051 Depth: 0 Loop: 5
# Score: 0.94459051 Depth: 0 Loop: 6
# Score: 0.94459051 Depth: 0 Loop: 7
# Score: 0.94459051 Depth: 0 Loop: 8
# Score: 0.94459051 Depth: 0 Loop: 9
# Score: 0.94459051 Depth: 0 Loop: 10
# Score: 0.94459051 Depth: 0 Loop: 11
# Score: 0.94459051 Depth: 0 Loop: 12
# Score: 0.94459051 Depth: 0 Loop: 13
# Score: 0.94459051 Depth: 0 Loop: 14
# Score: 0.94459051 Depth: 0 Loop: 15
# Score: 0.94459051 Depth: 0 Loop: 16
# Score: 0.94459051 Depth: 0 Loop: 17
# Score: 0.94459051 Depth: 0 Loop: 18
# Score: 0.94459051 Depth: 0 Loop: 19
# Score: 0.94459051 Depth: 0 Loop: 20
# Score: 0.94459051 Depth: 0 Loop: 21
# Score: 0.94459051 Depth: 0 Loop: 22
# Score: 0.94459051 Depth: 0 Loop: 23
# Score: 0.94459051 Depth: 0 Loop: 24
# Score: 0.94459051 Depth: 0 Loop: 25
# Score: 0.94459051 Depth: 0 Loop: 26
# Score: 0.94459051 Depth: 0 Loop: 27
# Score: 0.94459051 Depth: 0 Loop: 28
# Score: 0.94459051 Depth: 0 Loop: 29
# Score: 0.94459051 Depth: 0 Loop: 30
# Score: 0.94459051 Depth: 0 Loop: 31
# Score: 0.94459051 Depth: 0 Loop: 32
# Score: 0.94459051 Depth: 0 Loop: 33
# Score: 0.94459051 Depth: 0 Loop: 34
# Score: 0.94459051 Depth: 0 Loop: 35
# Score: 0.94459051 Depth: 0 Loop: 36
# Score: 0.94459051 Depth: 0 Loop: 37
# Score: 0.94459051 Depth: 0 Loop: 38
# Score: 0.94459051 Depth: 0 Loop: 39
# Score: 0.94459051 Depth: 0 Loop: 40
# Score: 0.94459051 Depth: 0 Loop: 41
# Score: 0.94459051 Depth: 0 Loop: 42
# Score: 0.94459051 Depth: 0 Loop: 43
# Score: 0.94459051 Depth: 0 Loop: 44
# Score: 0.94459051 Depth: 0 Loop: 45
# Score: 0.94459051 Depth: 0 Loop: 46
# Score: 0.94459051 Depth: 0 Loop: 47
# Score: 0.94459051 Depth: 0 Loop: 48
# Score: 0.94459051 Depth: 0 Loop: 49
# Score: 0.94459051 Depth: 0 Loop: 50
# Score: 0.94459051 Depth: 0 Loop: 51
# Score: 0.94459051 Depth: 0 Loop: 52
# Score: 0.94459051 Depth: 0 Loop: 53
# Score: 0.94459051 Depth: 0 Loop: 54
# Score: 0.94459051 Depth: 0 Loop: 55
# Score: 0.94459051 Depth: 0 Loop: 56
# Score: 0.94459051 Depth: 0 Loop: 57
# Score: 0.94459051 Depth: 0 Loop: 58
# Score: 0.94459051 Depth: 0 Loop: 59
# Score: 0.94459051 Depth: 0 Loop: 60
# Score: 0.94459051 Depth: 0 Loop: 61
# Score: 0.94459051 Depth: 0 Loop: 62
# Score: 0.94459051 Depth: 0 Loop: 63
# Score: 0.94459051 Depth: 0 Loop: 64
# Score: 0.94459051 Depth: 0 Loop: 65
# Score: 0.94459051 Depth: 0 Loop: 66
# Score: 0.94459051 Depth: 0 Loop: 67
# Score: 0.94459051 Depth: 0 Loop: 68
# Score: 0.94459051 Depth: 0 Loop: 69
# Score: 0.94459051 Depth: 0 Loop: 70
# Score: 0.94459051 Depth: 0 Loop: 71
# Score: 0.94459051 Depth: 0 Loop: 72
# Score: 0.94459051 Depth: 0 Loop: 73
# Score: 0.94459051 Depth: 0 Loop: 74
# Score: 0.94459051 Depth: 0 Loop: 75
# Score: 0.94459051 Depth: 0 Loop: 76
# Score: 0.94459051 Depth: 0 Loop: 77
# Score: 0.94459051 Depth: 0 Loop: 78
# Score: 0.94459051 Depth: 0 Loop: 79
# Score: 0.94459051 Depth: 0 Loop: 80
# Score: 0.94459051 Depth: 0 Loop: 81
# Score: 0.94459051 Depth: 0 Loop: 82
# Score: 0.94459051 Depth: 0 Loop: 83
# Score: 0.94459051 Depth: 0 Loop: 84
# Score: 0.94459051 Depth: 0 Loop: 85
# Score: 0.94459051 Depth: 0 Loop: 86
# Score: 0.94459051 Depth: 0 Loop: 87
# Score: 0.94459051 Depth: 0 Loop: 88
# Score: 0.94459051 Depth: 0 Loop: 89
# Score: 0.94459051 Depth: 0 Loop: 90
# Score: 0.94459051 Depth: 0 Loop: 91
# Score: 0.94459051 Depth: 0 Loop: 92
# Score: 0.94459051 Depth: 0 Loop: 93
# Score: 0.94459051 Depth: 0 Loop: 94
# Score: 0.94459051 Depth: 0 Loop: 95
# Score: 0.94459051 Depth: 0 Loop: 96
# Score: 0.94459051 Depth: 0 Loop: 97
# Score: 0.94459051 Depth: 0 Loop: 98
# Score: 0.94459051 Depth: 0 Loop: 99
# Score: 0.94459051 Depth: 0 Loop: 100
# Score: 0.94459051 Depth: 0 Loop: 101
# Score: 0.94459051 Depth: 0 Loop: 102
# Score: 0.94459051 Depth: 0 Loop: 103
# Score: 0.94459051 Depth: 0 Loop: 104
# Score: 0.94459051 Depth: 0 Loop: 105
# Score: 0.94459051 Depth: 0 Loop: 106
# Score: 0.94459051 Depth: 0 Loop: 107
# Score: 0.94459051 Depth: 0 Loop: 108
# Score: 0.94459051 Depth: 0 Loop: 109
# Score: 0.94459051 Depth: 0 Loop: 110
# Score: 0.94459051 Depth: 0 Loop: 111
# Score: 0.94459051 Depth: 0 Loop: 112
# Score: 0.94459051 Depth: 0 Loop: 113
# Score: 0.94459051 Depth: 0 Loop: 114
# Score: 0.94459051 Depth: 0 Loop: 115
# Score: 0.94459051 Depth: 0 Loop: 116
# Score: 0.94459051 Depth: 0 Loop: 117
# Score: 0.94459051 Depth: 0 Loop: 118
# Score: 0.94459051 Depth: 0 Loop: 119
# Score: 0.94459051 Depth: 0 Loop: 120
# Score: 0.94459051 Depth: 0 Loop: 121
# Score: 0.94459051 Depth: 0 Loop: 122
# Score: 0.94459051 Depth: 0 Loop: 123
# Score: 0.94459051 Depth: 0 Loop: 124
# Score: 0.94459051 Depth: 0 Loop: 125
# Score: 0.94459051 Depth: 0 Loop: 126
# Score: 0.94459051 Depth: 0 Loop: 127
# Score: 0.94459051 Depth: 0 Loop: 128
# Score: 0.94459051 Depth: 0 Loop: 129
# Score: 0.94459051 Depth: 0 Loop: 130
# Score: 0.94459051 Depth: 0 Loop: 131
# Score: 0.94459051 Depth: 0 Loop: 132
# Score: 0.94459051 Depth: 0 Loop: 133
# Score: 0.94459051 Depth: 0 Loop: 134
# Score: 0.94459051 Depth: 0 Loop: 135
# Score: 0.94459051 Depth: 0 Loop: 136
# Score: 0.94459051 Depth: 0 Loop: 137
# Score: 0.94459051 Depth: 0 Loop: 138
# Score: 0.94459051 Depth: 0 Loop: 139
# Score: 0.94459051 Depth: 0 Loop: 140
# Score: 0.94459051 Depth: 0 Loop: 141
# Score: 0.94459051 Depth: 0 Loop: 142
# Score: 0.94459051 Depth: 0 Loop: 143
# Score: 0.94459051 Depth: 0 Loop: 144
# Score: 0.94459051 Depth: 0 Loop: 145
# Score: 0.94459051 Depth: 0 Loop: 146
# Score: 0.94459051 Depth: 0 Loop: 147
# Score: 0.94459051 Depth: 0 Loop: 148
# Score: 0.94459051 Depth: 0 Loop: 149
# Score: 0.94459051 Depth: 0 Loop: 150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-07a8823da76f> in <module>
#       4 #img = ImgHelper.load_ppm_image("resources/00001_00027.ppm")
#       5
# ----> 6 ans = DegGen.remoteDegenerate(img, DegGen._smooth)
#       7 scipyMisc.imsave("resources/remoteDegenerated.png",ans[1])
#       8 plt.imshow(ans[1])
#
# ~\source\repos\Medusa\Medusa\Degeneration.py in remoteDegenerate(image, alternationfn, decay, iterations, maxloops)
#     118
#     119         #We are working remote, we need to take a short break
# --> 120         time.sleep(1.1)
#     121     #We return the lastImg, this can be something not that good if we just reach maxloops!
#     122     return lastScore,lastImg
#
# KeyboardInterrupt:
